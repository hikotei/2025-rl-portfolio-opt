# %%
import os
import pandas as pd

from datetime import datetime
from utils.config import DRLConfig
from utils.drl_train import training_pipeline

# %load_ext autoreload
# %autoreload 2

# %%
df_ret = pd.read_parquet("../data/returns.parquet")
df_prices = pd.read_parquet("../data/prices.parquet")
df_vol = pd.read_parquet("../data/vola.parquet")

# %% [markdown]
# To view the logs:
# 1. Open a terminal or command prompt.
# 2. Navigate to the directory *containing* the `logs` directory (i.e., the root of this repository).
# 3. Run the command: `tensorboard --logdir logs/`
# 4. Open the URL provided by TensorBoard (usually http://localhost:6006/) in your web browser.
#
# You should see experiments named like `PPO_WindowX_AgentY_SeedZ`.

# %%
# Create timestamp for this run
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

# Create configuration
config = DRLConfig(

    # Window configuration
    n_windows=1,  # 10 in paper
    agents_per_window=1,  # 5 in paper
    base_start_year=2006,
    num_train_years=5,
    num_val_years=1,
    num_test_years=1,

    # Environment parameters
    env_window_size=60,
    transaction_cost=0.0,
    initial_balance=100_000,
    reward_scaling=1.0,
    eta_dsr=1 / 252,

    # Training parameters
    n_envs=10, 
    total_timesteps_per_round= 1000, # 7_500_000, # 7_500_000 in paper
    n_steps_per_env=252 * 3,
    batch_size=1260,
    n_epochs=16,
    gamma=0.9,
    gae_lambda=0.9,
    clip_range=0.25,
    log_std_init=-1.0,

    # Learning rate parameters
    initial_lr=3e-4,
    final_lr=1e-5,

    # Paths
    model_save_dir=f"../models/{timestamp}",
    tensorboard_log_dir=f"../logs/{timestamp}",
)

# %%
# Run training pipeline
results, all_portfolios = training_pipeline(
    drl_config = config,
    df_prices = df_prices,
    df_ret = df_ret,
    df_vol = df_vol
)

# Convert results to DataFrame
results_df = pd.DataFrame(results)
# Out:
# --- Starting Window 1/1 (Train Year Start: 2006) ---
#   Train Period: 2006-01-01 to 2010-12-31
#   Val Period  : 2011-01-01 to 2011-12-31
#   Test Period : 2012-01-01 to 2012-12-31
#   Training Agent 1/1 with seed 0...
# Output()
#     Starting training for 1000 timesteps...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Training complete. Trained for 1000 timesteps.
# TensorBoard logs for experiment 'PPO_Seed0' saved in directory: ../logs/20250602_222315
#     Evaluating agent on validation set...
# DEBUG
# eval env current step at start of eval 1569
#     Validation Mean Reward: -11.6248
#     Agent saved to: ../models/20250602_222315/agent_seed0_valrew-11.62.zip
#     Running backtest evaluation...
# DEBUG
# eval env current step at start of eval 1821

# %%
all_portfolios[0].print_summary()
# Out:
# === Current State ===
# Initial Balance: $100,000.00
# Portfolio Value: $102,593.24
# Cash: $18,349.61
# Cash Weight: 17.89%
#
# Current Holdings:
# | Asset   |   Shares | Weight   | Value       |
# |:--------|---------:|:---------|:------------|
# | XLK     |      368 | 8.74%    | $ 8,962.42  |
# | XLB     |      308 | 8.73%    | $ 8,954.19  |
# | XLU     |      403 | 9.09%    | $ 9,326.51  |
# | XLY     |      220 | 8.71%    | $ 8,940.33  |
# | XLV     |      306 | 9.75%    | $ 9,998.63  |
# | XLE     |      198 | 8.74%    | $ 8,970.67  |
# | XLI     |      306 | 8.95%    | $ 9,184.51  |
# | XLF     |      964 | 9.91%    | $ 10,167.07 |
# | XLP     |      386 | 9.49%    | $ 9,739.30  |
#
# === Performance Metrics ===
# | Metrics                   |      Value |
# |:--------------------------|-----------:|
# | Annual return             |  0.0347251 |
# | Cumulative returns        |  0.0259324 |
# | Annual volatility         |  0.105692  |
# | Sharpe ratio              |  0.375821  |
# | Calmar ratio              |  0.478773  |
# | Stability                 |  0.904411  |
# | Max drawdown              | -0.0725294 |
# | Omega ratio               |  1.06552   |
# | Sortino ratio             |  0.580735  |
# | Skew                      |  0.0754232 |
# | Kurtosis                  |  0.666055  |
# | Tail ratio                |  1.03591   |
# | Daily value at risk (95%) | -0.0116473 |
# | Portfolio turnover (in %) |  1.05254   |
#
# === History & Configuration ===
# Number of Records: 190
# Date Range: 2012-03-27 00:00:00 to 2012-12-27 00:00:00
#
# Assets:
#   - XLF
#   - XLK
#   - XLV
#   - XLY
#   - XLP
#   - XLE
#   - XLI
#   - XLU
#   - XLB
#   - XLRE
#   - XLC

# %%
results_filename = f"backtest_results_summary_{timestamp}.csv"
results_save_path = os.path.join(config.model_save_dir, results_filename)
results_df.to_csv(results_save_path, index=False)
print(f"\nBacktest results summary saved to: {results_save_path}")
print("\nFinal Results DataFrame:")
results_df.head()
# Out:
# Backtest results summary saved to: ../models/20250602_222315/backtest_results_summary_20250602_222315.csv
#
# Final Results DataFrame:
#    window                                    best_agent_path     status  \
# 0       1  ../models/20250602_222315/agent_seed0_valrew-1...  completed
#
#                                              metrics
# 0  {'n_eval_episodes': 1, 'mean_reward': 17.10875...
